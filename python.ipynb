# %% [markdown]
# <a href="https://colab.research.google.com/github/jafludo/Python-machine_learning/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
import io
from pandas.plotting import scatter_matrix
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import scale
from sklearn.preprocessing import MinMaxScaler
from sklearn import cluster

# %%
training = pd.read_csv('cs-training.csv', index_col=0)
training
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1                      1                              0.766127   45
# 2                      0                              0.957151   40
# 3                      0                              0.658180   38
# 4                      0                              0.233810   30
# 5                      0                              0.907239   49
# ...                  ...                                   ...  ...
# 149996                 0                              0.040674   74
# 149997                 0                              0.299745   44
# 149998                 0                              0.246044   58
# 149999                 0                              0.000000   30
# 150000                 0                              0.850283   64
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 1                                          2     0.802982         9120.0
# ...

# %%
test = pd.read_csv('cs-test.csv', index_col=0)
test
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1                    NaN                              0.885519   43
# 2                    NaN                              0.463295   57
# 3                    NaN                              0.043275   59
# 4                    NaN                              0.280308   38
# 5                    NaN                              1.000000   27
# ...                  ...                                   ...  ...
# 101499               NaN                              0.282653   24
# 101500               NaN                              0.922156   36
# 101501               NaN                              0.081596   70
# 101502               NaN                              0.335457   56
# 101503               NaN                              0.441842   29
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 1                                          0     0.177513         5700.0
# ...

# %%
training['MonthlyIncome'].replace(np.nan, 0, inplace=True)
test['MonthlyIncome'].replace(np.nan, 0, inplace=True)
training['NumberOfDependents'].replace(np.nan, 0, inplace=True)
test['NumberOfDependents'].replace(np.nan, 0, inplace=True)
# Out:
# C:\Users\mathi\anaconda3\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
training = training.dropna()

# %%
training = training.fillna(method='bfill')

# %%
training.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     120269.000000                         120269.000000  120269.000000
# mean           0.069486                              5.899873      51.289792
# std            0.254280                            257.040685      14.426684
# min            0.000000                              0.000000       0.000000
# 25%            0.000000                              0.035084      40.000000
# 50%            0.000000                              0.177282      51.000000
# 75%            0.000000                              0.579428      61.000000
# max            1.000000                          50708.000000     103.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         120269.000000  120269.000000   1.202690e+05
# mean                               0.381769      26.598777   6.670221e+03
# ...

# %%
test.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count               0.0                         101503.000000  101503.000000
# mean                NaN                              5.310000      52.405436
# std                 NaN                            196.156039      14.779756
# min                 NaN                              0.000000      21.000000
# 25%                 NaN                              0.030131      41.000000
# 50%                 NaN                              0.152586      52.000000
# 75%                 NaN                              0.564225      63.000000
# max                 NaN                          21821.000000     104.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         101503.000000  101503.000000   1.015030e+05
# mean                               0.453770     344.475020   5.497373e+03
# ...

# %%
training[training['age'] < 18]
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 65696                 0                                   1.0    0
#
#        NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 65696                                     1   0.436927         6000.0
#
#        NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 65696                                6                        0
#
#        NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 65696                             2                                     0
#
#        NumberOfDependents
# 65696                 2.0

# %%
plt.figure(figsize=(8,3))
sns.boxplot(training['age'])
# Out:
# C:\Users\mathi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
#k-means
scatter_mat = scatter_matrix(training, figsize = (16,10))

# %%
corr = training.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
training.loc[training['age'] < 18, 'age'] = training['age'].median()

# %%
min_max = MinMaxScaler()
min_max
min_max.fit(training)
min_max.data_min_
min_max.data_max_
min_max.transform(training)
pd.DataFrame(min_max.transform(training), columns = training.columns, index=training.index)# .boxplot(rot = 45)
df_minmax = min_max.fit_transform(training)

# %%
# Kmeans sur le df_minmax
kmeans_minmax = cluster.KMeans(n_clusters=4, random_state=42)
# kmeans_minmax
kmeans_minmax.fit(df_minmax)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
#regression logistique
X_train, X_test, y_train, y_test = train_test_split(training.iloc[:,1:], training.iloc[:,0], random_state=42)

# %%
scaler = StandardScaler().fit(X_train)

X_train_scaled = scaler.transform(X_train) 
X_test_scaled = scaler.transform(X_test)

# %%
logit = LogisticRegression(random_state=42)
l_model = logit.fit(X_train_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18900/3993393758.py in <module>
#       1 logit = LogisticRegression(random_state=42)
# ----> 2 l_model = logit.fit(X_train_scaled, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# ...

# %%
logit_scores_proba  = l_model.predict_proba(X_test_scaled)
logit_scores = logit_scores_proba[:,1]

# %%
def plot_roc(y_test, y_predict):
    fpr, tpr, _ = roc_curve(y_test, y_predict)
    roc_auc = auc(fpr,tpr)
    print(roc_auc)
    plt.figure(figsize=(10,8))
    plt.title("ROC curve")
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0,1], [0,1],'r--')
    plt.legend(loc="lower right")
plot_roc(y_test, logit_scores)
